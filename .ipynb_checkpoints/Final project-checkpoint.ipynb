# %% [markdown]
# # Final project

# %% [markdown]
# 1. [The setup](#The-setup)
# 2. [The raw data](#The-raw-data)
# 3. [The processed data](#The-processed-data)
# 4. [The data](#The-data)
# 5. [The visualized data](#The-visualized-data)
# 6. [Preparing the data](#Preparing-the-data)
# 7. [Training the network](#Training-the-network)
# 8. [Checking out predictions](#Checking-out-predictions)

# %% [markdown]
# ## The setup

# %% [markdown]
# Import the libraries:

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## The raw data

# %% [markdown]
# The first step when working with neural networks is to load the data which we'll work with.

# %% [markdown]
# We load information related to each team by year.

# %%
teams = pd.read_csv('Teams.csv',index_col=0).reset_index()
teams.head()
# Out:
#    yearID lgID teamID franchID divID  Rank   G  Ghome   W   L  ...  DP     FP  \
# 0    1871  NaN    BS1      BNA   NaN     3  31    NaN  20  10  ...  24  0.834
# 1    1871  NaN    CH1      CNA   NaN     2  28    NaN  19   9  ...  16  0.829
# 2    1871  NaN    CL1      CFC   NaN     8  29    NaN  10  19  ...  15  0.818
# 3    1871  NaN    FW1      KEK   NaN     7  19    NaN   7  12  ...   8  0.803
# 4    1871  NaN    NY2      NNA   NaN     5  33    NaN  16  17  ...  14  0.840
#
#                       name                          park  attendance  BPF  \
# 0     Boston Red Stockings           South End Grounds I         NaN  103
# 1  Chicago White Stockings       Union Base-Ball Grounds         NaN  104
# 2   Cleveland Forest Citys  National Association Grounds         NaN   96
# 3     Fort Wayne Kekiongas                Hamilton Field         NaN  101
# 4         New York Mutuals      Union Grounds (Brooklyn)         NaN   90
#
#    PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0   98       BOS             BS1          BS1
# 1  102       CHI             CH1          CH1
# 2  100       CLE             CL1          CL1
# 3  107       KEK             FW1          FW1
# 4   88       NYU             NY2          NY2
#
# [5 rows x 48 columns]

# %%
len(teams)
# Out:
# 2925

# %% [markdown]
# And we load information related to team salaries by player and by year.

# %%
salaries = pd.read_csv('Salaries.csv',index_col=0).reset_index()
salaries.head()
# Out:
#    yearID teamID lgID   playerID  salary
# 0    1985    ATL   NL  barkele01  870000
# 1    1985    ATL   NL  bedrost01  550000
# 2    1985    ATL   NL  benedbr01  545000
# 3    1985    ATL   NL   campri01  633333
# 4    1985    ATL   NL  ceronri01  625000

# %%
len(salaries)
# Out:
# 26428

# %% [markdown]
# ## The processed data

# %% [markdown]
# ### Match yearly information

# %% [markdown]
# Remove the yearly information from teams based on the yearly information we have on salaries.

# %%
first_year = salaries['yearID'][0]
first_year
# Out:
# 1985

# %%
last_year = salaries['yearID'][len(salaries) - 1]
last_year
# Out:
# 2016

# %%
teams
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...   DP  \
# 0       1871  NaN    BS1      BNA   NaN     3   31    NaN  20  10  ...   24
# 1       1871  NaN    CH1      CNA   NaN     2   28    NaN  19   9  ...   16
# 2       1871  NaN    CL1      CFC   NaN     8   29    NaN  10  19  ...   15
# 3       1871  NaN    FW1      KEK   NaN     7   19    NaN   7  12  ...    8
# 4       1871  NaN    NY2      NNA   NaN     5   33    NaN  16  17  ...   14
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ..  ...  ...
# 2920    2019   NL    SLN      STL     C     1  162   81.0  91  71  ...  168
# 2921    2019   AL    TBA      TBD     E     2  162   81.0  96  66  ...  126
# 2922    2019   AL    TEX      TEX     W     3  162   81.0  78  84  ...  143
# 2923    2019   AL    TOR      TOR     E     4  162   81.0  67  95  ...  141
# 2924    2019   NL    WAS      WSN     E     2  162   81.0  93  69  ...  111
#
#          FP                     name                          park  \
# 0     0.834     Boston Red Stockings           South End Grounds I
# 1     0.829  Chicago White Stockings       Union Base-Ball Grounds
# 2     0.818   Cleveland Forest Citys  National Association Grounds
# 3     0.803     Fort Wayne Kekiongas                Hamilton Field
# 4     0.840         New York Mutuals      Union Grounds (Brooklyn)
# ...     ...                      ...                           ...
# 2920  0.989      St. Louis Cardinals             Busch Stadium III
# 2921  0.985           Tampa Bay Rays               Tropicana Field
# 2922  0.982            Texas Rangers  Globe Life Park in Arlington
# 2923  0.984        Toronto Blue Jays                 Rogers Centre
# 2924  0.985     Washington Nationals                Nationals Park
#
#       attendance  BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 0            NaN  103   98       BOS             BS1          BS1
# 1            NaN  104  102       CHI             CH1          CH1
# 2            NaN   96  100       CLE             CL1          CL1
# 3            NaN  101  107       KEK             FW1          FW1
# 4            NaN   90   88       NYU             NY2          NY2
# ...          ...  ...  ...       ...             ...          ...
# 2920   3480393.0   98   97       STL             SLN          SLN
# 2921   1178735.0   97   96       TBR             TBA          TBA
# 2922   2132994.0  111  112       TEX             TEX          TEX
# 2923   1750114.0   97   98       TOR             TOR          TOR
# 2924   2259781.0  106  104       WSN             MON          WAS
#
# [2925 rows x 48 columns]

# %%
teams_processed = teams[teams['yearID'] >= first_year]
teams_processed = teams_processed[teams['yearID'] <= last_year]
teams_processed
# Out:
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...   DP  \
# 1917    1985   NL    ATL      ATL     W     5  162   81.0  66  96  ...  197
# 1918    1985   AL    BAL      BAL     E     4  161   81.0  83  78  ...  168
# 1919    1985   AL    BOS      BOS     E     5  163   81.0  81  81  ...  161
# 1920    1985   AL    CAL      ANA     W     2  162   79.0  90  72  ...  202
# 1921    1985   AL    CHA      CHW     W     3  163   81.0  85  77  ...  152
# ...      ...  ...    ...      ...   ...   ...  ...    ...  ..  ..  ...  ...
# 2830    2016   NL    SLN      STL     C     2  162   81.0  86  76  ...  169
# 2831    2016   AL    TBA      TBD     E     5  162   81.0  68  94  ...  129
# 2832    2016   AL    TEX      TEX     W     1  162   81.0  95  67  ...  190
# 2833    2016   AL    TOR      TOR     E     2  162   81.0  89  73  ...  144
# 2834    2016   NL    WAS      WSN     E     1  162   81.0  95  67  ...  142
#
#          FP                  name                           park  attendance  \
# 1917  0.976        Atlanta Braves  Atlanta-Fulton County Stadium   1350137.0
# 1918  0.979     Baltimore Orioles               Memorial Stadium   2132387.0
# 1919  0.977        Boston Red Sox                 Fenway Park II   1786633.0
# 1920  0.982     California Angels                Anaheim Stadium   2567427.0
# 1921  0.982     Chicago White Sox                  Comiskey Park   1669888.0
# ...     ...                   ...                            ...         ...
# 2830  0.983   St. Louis Cardinals              Busch Stadium III   3444490.0
# 2831  0.984        Tampa Bay Rays                Tropicana Field   1286163.0
# 2832  0.984         Texas Rangers  Rangers Ballpark in Arlington   2710402.0
# 2833  0.986     Toronto Blue Jays                  Rogers Centre   3392099.0
# 2834  0.988  Washington Nationals                 Nationals Park   2481938.0
#
#       BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 1917  105  106       ATL             ATL          ATL
# 1918   97   97       BAL             BAL          BAL
# 1919  104  104       BOS             BOS          BOS
# 1920  100  100       CAL             CAL          CAL
# 1921  104  104       CHW             CHA          CHA
# ...   ...  ...       ...             ...          ...
# 2830  100   99       STL             SLN          SLN
# 2831   93   94       TBR             TBA          TBA
# 2832  106  105       TEX             TEX          TEX
# 2833  111  110       TOR             TOR          TOR
# 2834  100   98       WSN             MON          WAS
#
# [918 rows x 48 columns]

# %%
len(teams_processed)
# Out:
# 918

# %% [markdown]
# ### Salaries information

# %% [markdown]
# Get all salaries by team and by year.

# %%
salaries_processed = salaries.groupby(['yearID', 'teamID'])
salaries_processed.sum()
# Out:
#                   salary
# yearID teamID
# 1985   ATL      14807000
#        BAL      11560712
#        BOS      10897560
#        CAL      14427894
#        CHA       9846178
# ...                  ...
# 2016   SLN     143053500
#        TBA      57097310
#        TEX     176038723
#        TOR     138701700
#        WAS     141652646
#
# [918 rows x 1 columns]

# %%
len(salaries_processed)
# Out:
# 918

# %% [markdown]
# ### Combine salaries information into teams information

# %% [markdown]
# First, let's remove information we won't use:

# %%
teams_processed.head()
# Out:
#       yearID lgID teamID franchID divID  Rank    G  Ghome   W   L  ...   DP  \
# 1917    1985   NL    ATL      ATL     W     5  162   81.0  66  96  ...  197
# 1918    1985   AL    BAL      BAL     E     4  161   81.0  83  78  ...  168
# 1919    1985   AL    BOS      BOS     E     5  163   81.0  81  81  ...  161
# 1920    1985   AL    CAL      ANA     W     2  162   79.0  90  72  ...  202
# 1921    1985   AL    CHA      CHW     W     3  163   81.0  85  77  ...  152
#
#          FP               name                           park  attendance  \
# 1917  0.976     Atlanta Braves  Atlanta-Fulton County Stadium   1350137.0
# 1918  0.979  Baltimore Orioles               Memorial Stadium   2132387.0
# 1919  0.977     Boston Red Sox                 Fenway Park II   1786633.0
# 1920  0.982  California Angels                Anaheim Stadium   2567427.0
# 1921  0.982  Chicago White Sox                  Comiskey Park   1669888.0
#
#       BPF  PPF  teamIDBR  teamIDlahman45  teamIDretro
# 1917  105  106       ATL             ATL          ATL
# 1918   97   97       BAL             BAL          BAL
# 1919  104  104       BOS             BOS          BOS
# 1920  100  100       CAL             CAL          CAL
# 1921  104  104       CHW             CHA          CHA
#
# [5 rows x 48 columns]

# %%
fields_to_drop = ['yearID', 'lgID', 'teamID', 'Rank', 'franchID', 'divID', 'DivWin', 'WCWin', 'LgWin', 'WSWin', 'HBP', 'SF', 'RA', 'ER', 'ERA', 'CG', 'SHO', 'SV', 'IPouts', 'HA', 'HRA', 'BBA', 'SOA', 'E', 'DP', 'FP', 'name', 'park', 'attendance', 'BPF', 'PPF', 'teamIDBR', 'teamIDlahman45', 'teamIDretro']

# %%
teams_processed = teams_processed.drop(fields_to_drop, axis=1)
teams_processed.head()
# Out:
#         G  Ghome   W   L    R    AB     H   2B  3B   HR     BB     SO     SB  \
# 1917  162   81.0  66  96  632  5526  1359  213  28  126  553.0  849.0   72.0
# 1918  161   81.0  83  78  818  5517  1451  234  22  214  604.0  908.0   69.0
# 1919  163   81.0  81  81  800  5720  1615  292  31  162  562.0  816.0   66.0
# 1920  162   79.0  90  72  732  5442  1364  215  31  153  648.0  902.0  106.0
# 1921  163   81.0  85  77  736  5470  1386  247  37  146  471.0  843.0  108.0
#
#         CS
# 1917  52.0
# 1918  43.0
# 1919  27.0
# 1920  51.0
# 1921  56.0

# %% [markdown]
# Add salary column to teams information:

# %%
salaries_processed.sum()
# Out:
#                   salary
# yearID teamID
# 1985   ATL      14807000
#        BAL      11560712
#        BOS      10897560
#        CAL      14427894
#        CHA       9846178
# ...                  ...
# 2016   SLN     143053500
#        TBA      57097310
#        TEX     176038723
#        TOR     138701700
#        WAS     141652646
#
# [918 rows x 1 columns]

# %%
salaries_to_include = []

for salary in salaries_processed.sum()['salary']:
    salaries_to_include.append(salary)

# %%
len(salaries_to_include)
# Out:
# 918

# %%
teams_processed['salaries'] = salaries_to_include

# %% [markdown]
# ## The data

# %%
teams_processed
# Out:
#         G  Ghome   W   L    R    AB     H   2B  3B   HR     BB      SO     SB  \
# 1917  162   81.0  66  96  632  5526  1359  213  28  126  553.0   849.0   72.0
# 1918  161   81.0  83  78  818  5517  1451  234  22  214  604.0   908.0   69.0
# 1919  163   81.0  81  81  800  5720  1615  292  31  162  562.0   816.0   66.0
# 1920  162   79.0  90  72  732  5442  1364  215  31  153  648.0   902.0  106.0
# 1921  163   81.0  85  77  736  5470  1386  247  37  146  471.0   843.0  108.0
# ...   ...    ...  ..  ..  ...   ...   ...  ...  ..  ...    ...     ...    ...
# 2830  162   81.0  86  76  779  5548  1415  299  32  225  526.0  1318.0   35.0
# 2831  162   81.0  68  94  672  5481  1333  288  32  216  449.0  1482.0   60.0
# 2832  162   81.0  95  67  765  5525  1446  257  23  215  436.0  1220.0   99.0
# 2833  162   81.0  89  73  759  5479  1358  276  18  221  632.0  1362.0   54.0
# 2834  162   81.0  95  67  763  5490  1403  268  29  203  536.0  1252.0  121.0
#
#         CS   salaries
# 1917  52.0   14807000
# 1918  43.0   11560712
# 1919  27.0   10897560
# 1920  51.0   14427894
# 1921  56.0    9846178
# ...    ...        ...
# 2830  26.0  143053500
# 2831  37.0   57097310
# 2832  36.0  176038723
# 2833  24.0  138701700
# 2834  39.0  141652646
#
# [918 rows x 15 columns]

# %% [markdown]
# ## Preparing the data

# %% [markdown]
# To use our data in a format that gives the best results, we'll add some processing.

# %% [markdown]
# ### Scaling target variables
#
# To make training the network easier, we'll standardize each of the continuous variables. That is, we'll shift and scale the variables such that they have zero mean and a standard deviation of 1.
#
# The scaling factors will be saved, so we can go backwards when we use the network for predictions.

# %%
quant_features = ['G', 'Ghome', 'W', 'L', 'R', 'AB', 'H', '2B', '3B', 'HR', 'BB', 'SO', 'SB', 'CS', 'salaries']

# Store scalings in a dictionary so we can convert back later
scaled_features = {}

for quant in quant_features:
    mean, std = teams_processed[quant].mean(), teams_processed[quant].std()
    scaled_features[quant] = [mean, std]
    teams_processed.loc[:, quant] = (teams_processed[quant] - mean) / std

teams_processed.head()
# Out:
#              G     Ghome         W         L         R        AB         H  \
# 1917  0.238315  0.236283 -1.177626  1.359403 -1.090497  0.188587 -0.671964
# 1918  0.123050  0.236283  0.258158 -0.164530  0.979429  0.158616  0.196764
# 1919  0.353580  0.236283  0.089242  0.089459  0.779113  0.834616  1.745365
# 1920  0.238315 -0.214200  0.849363 -0.672508  0.022366 -0.091137 -0.624750
# 1921  0.353580  0.236283  0.427073 -0.249193  0.066881  0.002104 -0.417011
#
#             2B        3B        HR        BB        SO        SB        CS  \
# 1917 -1.823706 -0.327234 -0.862271  0.363576 -1.226301 -0.877215  0.460311
# 1918 -1.208884 -0.987940  1.504623  1.050608 -0.857231 -0.958779 -0.123702
# 1919  0.489198  0.003119  0.106004  0.484817 -1.432730 -1.040344 -1.161946
# 1920 -1.765152  0.003119 -0.136065  1.643342 -0.894764  0.047179  0.395421
# 1921 -0.828279  0.663825 -0.324340 -0.741064 -1.263834  0.101555  0.719872
#
#       salaries
# 1917 -1.044463
# 1918 -1.119418
# 1919 -1.134730
# 1920 -1.053217
# 1921 -1.159006

# %%
scaled_features
# Out:
# {'G': [159.93246187363835, 8.675653937883181],
#  'Ghome': [79.95098039215686, 4.439683508919887],
#  'W': [79.94335511982571, 11.840223777056089],
#  'L': [79.94335511982571, 11.81154521179715],
#  'R': [729.9901960784314, 89.85830911056667],
#  'AB': [5469.3681917211325, 300.2957966515429],
#  'H': [1430.1623093681917, 105.90199794585986],
#  '2B': [275.2908496732026, 34.1561834388321],
#  '3B': [30.971677559912855, 9.081195810971472],
#  'HR': [158.05882352941177, 37.179525907493904],
#  'BB': [526.0108932461874, 74.2323409860844],
#  'SO': [1045.0381263616557, 159.86134145023848],
#  'SB': [104.26470588235294, 36.78083097526128],
#  'CS': [44.90631808278867, 15.410626117514742],
#  'salaries': [60042632.63180828, 43309923.775295034]}

# %% [markdown]
# ### Splitting the data into training, and validation sets
#
# We train our models in the training.
#
# We'll save the data for the last approximately 2 years to use as a test set after we've trained the network. We'll use this set to make predictions and compare them with the actual number of wins.

# %%
# Save data for approximately the last 2 years
test_data = teams_processed[-60:]

# Now remove the test data from the data set 
teams_processed = teams_processed[:-60]

# Separate the data into features (X) and targets (y)
target_fields = ['W']

features, targets = teams_processed.drop(target_fields, axis=1), teams_processed[target_fields]
test_features, test_targets = test_data.drop(target_fields, axis=1), test_data[target_fields]

# %%
len(test_data)
# Out:
# 60

# %%
len(teams_processed)
# Out:
# 858

# %%
features.head()
# Out:
#              G     Ghome         L         R        AB         H        2B  \
# 1917  0.238315  0.236283  1.359403 -1.090497  0.188587 -0.671964 -1.823706
# 1918  0.123050  0.236283 -0.164530  0.979429  0.158616  0.196764 -1.208884
# 1919  0.353580  0.236283  0.089459  0.779113  0.834616  1.745365  0.489198
# 1920  0.238315 -0.214200 -0.672508  0.022366 -0.091137 -0.624750 -1.765152
# 1921  0.353580  0.236283 -0.249193  0.066881  0.002104 -0.417011 -0.828279
#
#             3B        HR        BB        SO        SB        CS  salaries
# 1917 -0.327234 -0.862271  0.363576 -1.226301 -0.877215  0.460311 -1.044463
# 1918 -0.987940  1.504623  1.050608 -0.857231 -0.958779 -0.123702 -1.119418
# 1919  0.003119  0.106004  0.484817 -1.432730 -1.040344 -1.161946 -1.134730
# 1920  0.003119 -0.136065  1.643342 -0.894764  0.047179  0.395421 -1.053217
# 1921  0.663825 -0.324340 -0.741064 -1.263834  0.101555  0.719872 -1.159006

# %%
targets.head()
# Out:
#              W
# 1917 -1.177626
# 1918  0.258158
# 1919  0.089242
# 1920  0.849363
# 1921  0.427073

# %% [markdown]
# ## Training the network

# %% [markdown]
# First, we have to set the hyperparameters for the network. The goal here is to find hyperparameters such that the error on the training set is low, but we're not overfitting to the data.
#
# We'll use a simple sequential neural network with a single layer.

# %%
import keras
from keras.models import Sequential
from keras.layers import Input
from keras.layers.core import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %% [markdown]
# We can then use Keras to create a simple linear model (called Dense() in Keras) and optimize it using SGD to minimize our mean squared error (mse):

# %%
model = Sequential([Dense(1, input_shape=(14,))])
model.summary()
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_1 (Dense)              (None, 1)                 15
# =================================================================
# Total params: 15
# Trainable params: 15
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.get_weights()
# Out:
# [array([[ 0.5350345 ],
#         [ 0.08818269],
#         [-0.15207326],
#         [-0.12800568],
#         [-0.13558719],
#         [ 0.42134005],
#         [ 0.45816177],
#         [ 0.43252355],
#         [-0.29336467],
#         [ 0.5354821 ],
#         [-0.30430427],
#         [-0.33853793],
#         [ 0.4453321 ],
#         [ 0.15078086]], dtype=float32),
#  array([0.], dtype=float32)]

# %%
model.compile(optimizer='sgd', loss='mse')

# %% [markdown]
# The linear model created has set internal weights, which we can use to evaluate the loss function (MSE):

# %%
model.evaluate(features, targets, verbose=0)
# Out:
# 1.5200985700656207

# %% [markdown]
# And proceed to train our network:

# %%
model.fit(features, targets, batch_size=1, epochs=30)
# Out:
# WARNING:tensorflow:From /opt/anaconda3/envs/tf/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/30
# 858/858 [==============================] - 1s 1ms/step - loss: 0.0766
# Epoch 2/30
# 858/858 [==============================] - 1s 815us/step - loss: 0.0116
# Epoch 3/30
# 858/858 [==============================] - 1s 800us/step - loss: 0.0024
# Epoch 4/30
# 858/858 [==============================] - 1s 790us/step - loss: 0.0011
# Epoch 5/30
# 858/858 [==============================] - 1s 803us/step - loss: 0.0012
# Epoch 6/30
# 858/858 [==============================] - 1s 822us/step - loss: 8.5141e-04
# Epoch 7/30
# 858/858 [==============================] - 1s 987us/step - loss: 6.6357e-04
# Epoch 8/30
# 858/858 [==============================] - 1s 831us/step - loss: 6.4821e-04
# Epoch 9/30
# 858/858 [==============================] - 1s 795us/step - loss: 0.0011
# Epoch 10/30
# 858/858 [==============================] - 1s 814us/step - loss: 6.4089e-04
# Epoch 11/30
# 858/858 [==============================] - 1s 832us/step - loss: 0.0020
# Epoch 12/30
# 858/858 [==============================] - 1s 793us/step - loss: 5.9766e-04
# Epoch 13/30
# 858/858 [==============================] - 1s 830us/step - loss: 5.1225e-04
# Epoch 14/30
# 858/858 [==============================] - 1s 802us/step - loss: 6.6380e-04
# Epoch 15/30
# 858/858 [==============================] - 1s 816us/step - loss: 4.9001e-04
# Epoch 16/30
# 858/858 [==============================] - 1s 817us/step - loss: 5.0838e-04
# Epoch 17/30
# 858/858 [==============================] - 1s 816us/step - loss: 5.3812e-04
# Epoch 18/30
# 858/858 [==============================] - 1s 866us/step - loss: 7.0869e-04
# Epoch 19/30
# 858/858 [==============================] - 1s 817us/step - loss: 9.3366e-04
# Epoch 20/30
# 858/858 [==============================] - 1s 821us/step - loss: 4.3570e-04
# Epoch 21/30
# 858/858 [==============================] - 1s 813us/step - loss: 0.0011
# Epoch 22/30
# 858/858 [==============================] - 1s 816us/step - loss: 6.1049e-04
# Epoch 23/30
# 858/858 [==============================] - 1s 945us/step - loss: 9.4702e-04
# Epoch 24/30
# 858/858 [==============================] - 1s 862us/step - loss: 5.8378e-04
# Epoch 25/30
# 858/858 [==============================] - 1s 863us/step - loss: 6.3161e-04
# Epoch 26/30
# 858/858 [==============================] - 1s 816us/step - loss: 6.0056e-04
# Epoch 27/30
# 858/858 [==============================] - 1s 822us/step - loss: 6.4990e-04
# Epoch 28/30
# 858/858 [==============================] - 1s 814us/step - loss: 5.5953e-04
# Epoch 29/30
# 858/858 [==============================] - 1s 842us/step - loss: 5.3143e-04
# Epoch 30/30
# 858/858 [==============================] - 1s 793us/step - loss: 6.0592e-04

# %% [markdown]
# Once trained, we evaluate our network using the train data:

# %%
model.evaluate(test_features, test_targets, verbose=0)
# Out:
# 0.00031083579718445736

# %% [markdown]
# ## Checking out predictions

# %% [markdown]
# Finally, we'll use the test data to view how well our network is modeling the data:

# %%
test_features.head()
# Out:
#              G     Ghome         L         R        AB         H        2B  \
# 2775  0.238315  0.236283  0.258785 -0.111177  0.598183  0.602800  0.401367
# 2776  0.238315  0.236283  1.274740 -1.747086 -0.164399 -0.653078 -0.711170
# 2777  0.238315 -0.439441  0.089459 -0.189078  0.052055 -0.568094 -0.857556
# 2778  0.238315  0.236283  0.343447  0.200424  0.568212  0.612242  0.547753
# 2779  0.238315  0.236283  0.512773 -1.201783  0.211897 -0.464225 -0.447674
#
#             3B        HR        BB        SO        SB        CS  salaries
# 2775  1.875119 -0.109168 -0.485111  1.669959  0.754069 -0.058811  0.041362
# 2776 -1.428411 -1.561581 -0.741064  0.387598 -0.958779 -0.772604  0.271038
# 2777 -1.208175  1.585313 -1.455038  1.788812 -1.638481 -1.291727  1.269968
# 2778  0.223354  0.079107 -0.646765  0.644070 -0.904403 -1.161946  2.795220
# 2779 -0.437352 -0.593306 -1.643635  1.163270 -0.985968 -0.188592  1.208293

# %%
# Check out predictions on test data
mean, std = scaled_features['W']
predictions = model.predict(test_features).T * std + mean
predictions
# Out:
# array([[ 78.8382  ,  66.95381 ,  81.00407 ,  78.051994,  75.98895 ,
#          97.004456,  63.840057,  80.96922 ,  67.871635,  74.01653 ,
#          85.88387 ,  94.98843 ,  85.01405 ,  92.11452 ,  70.87659 ,
#          67.927734,  82.966064,  87.094   ,  90.00546 ,  67.841156,
#          62.910927,  98.02592 ,  73.945786,  75.953674,  84.04162 ,
#         100.02921 ,  79.88343 ,  88.029495,  93.04215 ,  83.09141 ,
#          68.77493 ,  67.94522 ,  89.07454 ,  93.127335,  77.95809 ,
#         104.102234,  67.89963 ,  93.952934,  74.97658 ,  86.08523 ,
#          83.9288  ,  80.96946 ,  74.04425 ,  91.15616 ,  78.93305 ,
#          72.851974,  58.842186,  84.097336,  86.974495,  68.91595 ,
#          70.84324 ,  78.97014 ,  67.92006 ,  86.021935,  87.01125 ,
#          86.01499 ,  67.84023 ,  95.06639 ,  89.02582 ,  94.996635]],
#       dtype=float32)

# %%
predictions = predictions.round(0)
predictions
# Out:
# array([[ 79.,  67.,  81.,  78.,  76.,  97.,  64.,  81.,  68.,  74.,  86.,
#          95.,  85.,  92.,  71.,  68.,  83.,  87.,  90.,  68.,  63.,  98.,
#          74.,  76.,  84., 100.,  80.,  88.,  93.,  83.,  69.,  68.,  89.,
#          93.,  78., 104.,  68.,  94.,  75.,  86.,  84.,  81.,  74.,  91.,
#          79.,  73.,  59.,  84.,  87.,  69.,  71.,  79.,  68.,  86.,  87.,
#          86.,  68.,  95.,  89.,  95.]], dtype=float32)

# %% [markdown]
# Check the real target data:

# %%
np.array(test_targets['W'] * std + mean)
# Out:
# array([ 79.,  67.,  81.,  78.,  76.,  97.,  64.,  81.,  68.,  74.,  86.,
#         95.,  85.,  92.,  71.,  68.,  83.,  87.,  90.,  68.,  63.,  98.,
#         74.,  76.,  84., 100.,  80.,  88.,  93.,  83.,  69.,  68.,  89.,
#         93.,  78., 103.,  68.,  94.,  75.,  86.,  84.,  81.,  74.,  91.,
#         79.,  73.,  59.,  84.,  87.,  69.,  71.,  78.,  68.,  86.,  87.,
#         86.,  68.,  95.,  89.,  95.])

# %% [markdown]
# Create a plot to compare our predictions against our target data:

# %%
# Configure plot
fig, ax = plt.subplots(figsize=(8,4))

ax.plot(predictions[0], label='Prediction')
ax.plot((test_targets['W'] * std + mean).values, label='Data')
ax.set_xlim(right=len(predictions[0]))
ax.legend()
